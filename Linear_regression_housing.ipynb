# %% [markdown]
# <a href="https://colab.research.google.com/github/nehxxa/Symbiosis_training_programs/blob/main/Linear_regression_housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("/content/housing.csv")
df.columns = column_names

# %%
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS' , 'NOX' , 'RM' ,'AGE' , 'DIS' , 'RAD' , 'TAX' , 'PTRATIO' , 'B' , 'LSTAT' ,'MEDV']

# %%
df
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 1    0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 2    0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 3    0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# 4    0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222.0
# ..       ...  ...    ...   ...    ...    ...   ...     ...  ...    ...
# 500  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 501  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 502  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 503  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 504  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       17.8  396.90   9.14  21.6
# 1       17.8  392.83   4.03  34.7
# ...

# %%
X = df.drop('MEDV', axis=1)
y = df['MEDV']

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200283  0.406251 -0.056132  0.420934 -0.218978  0.352701
# ZN      -0.200283  1.000000 -0.534022 -0.042550 -0.516574  0.311835 -0.569524
# INDUS    0.406251 -0.534022  1.000000  0.062350  0.764556 -0.391330  0.645543
# CHAS    -0.056132 -0.042550  0.062350  1.000000  0.091134  0.091497  0.086461
# NOX      0.420934 -0.516574  0.764556  0.091134  1.000000 -0.302127  0.731461
# RM      -0.218978  0.311835 -0.391330  0.091497 -0.302127  1.000000 -0.240211
# AGE      0.352701 -0.569524  0.645543  0.086461  0.731461 -0.240211  1.000000
# DIS     -0.379627  0.664395 -0.708848 -0.099109 -0.769221  0.205170 -0.747872
# RAD      0.625396 -0.311717  0.594167 -0.007907  0.611758 -0.209277  0.456232
# TAX      0.582568 -0.314351  0.720561 -0.035965  0.668141 -0.291680  0.506527
# PTRATIO  0.289394 -0.391713  0.380955 -0.122570  0.188918 -0.355116  0.261724
# ...

# %%
X_train = np.array(X)

# %%
from sklearn import datasets, decomposition
from sklearn.decomposition import PCA
pca = PCA(n_components=1)
principal_component = pca.fit_transform(X_train)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(principal_component, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(principal_component)

# %%
import matplotlib.pyplot as plt
plt.scatter(principal_component, y)
plt.plot(principal_component, y_pred, color='red')
plt.show()
